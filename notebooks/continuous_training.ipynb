# %% [markdown]
# <img src="http://developer.download.nvidia.com/compute/machine-learning/frameworks/nvidia_logo.png" style="width: 90px; float: right;">
#
# # HugeCTR Continuous Training

# %% [markdown]
# ## Overview
# The notebook introduces how to use the model oversubscription (a.k.a. Embedding Training Cache) feature in HugeCTR for the continuous training. The Model Oversubscription feature is designed to handle recommendation models with huge embedding table by means of incremental training method, which allows you to train such a model even the model size is much larger than the available GPU memory size.
#
# Model oversubscription currently supports the following features:
# - Support single-node multi-GPUs and multi-node multi-GPUs cases
# - Support both the host memory (HMEM)-based parameter server (PS) and the host memory cache (HMEM-Cache)-based PS
#   * For the HMEM-based PS, the embedding table size can scale up to the aggregate HMEM size of each node
#   * For the HMEM-Cache-based PS, the embedding table size can scale up to the SSD capacity
# - Provide the `get_incremental_model()` interface to get the updated embedding features during training
# - Support training from scratch or incremental training with existing sparse and dense models
#
# To learn more about the model oversubscription, please check the [Embedding Training Cache](../docs/hugectr_user_guide.md#embedding-training-cache).
#
# To learn how to use the APIs of model oversubscription, please check the [HugeCTR Python Interface](../docs/python_interface.md).
#
# ## Table of Contents
# -  [Installation](#1)
#    * [Get HugeCTR from NGC](#11)
#    * [Build HugeCTR from Source Code](#12)
# -  [Continuous Training](#2)
#    * [Data Preparation](#21)
#    * [Continuous Training with High-level API](#22)
#    * [Continuous Training with Low-level API](#23)

# %% [markdown]
# <a id="1"></a>
# ## Installation
#
# ### 1.1 Get HugeCTR from NGC
# The continuous training module is preinstalled in the [Merlin Training Container](https://ngc.nvidia.com/catalog/containers/nvidia:merlin:merlin-training): `nvcr.io/nvidia/merlin/merlin-training:21.11`.
#
# You can check the existence of required libraries by running the following Python code after launching this container.
# ```bash
# $ python3 -c "import hugectr"
# ```

# %% [markdown]
# ### 1.2 Build HugeCTR from Source Code
#
# If you want to build HugeCTR from the source code instead of using the NGC container, please refer to the [Setup development environment](../docs/hugectr_contributor_guide.md#setup-development-environment).

# %% [markdown]
# <a id="2"></a>
# ## Continuous Training
#
# <a id="21"></a>
# ### 2.1 Data Preparation
# 1. Download the Kaggle Criteo dataset using the following command:
#    ```shell
#    $ cd ${project_root}/tools
#    $ wget http://azuremlsampleexperiments.blob.core.windows.net/criteo/day_1.gz
#    ```
#
#    To preprocess the downloaded Kaggle Criteo dataset, we'll make the following operations:
#    * Reduce the amounts of data to speed up the preprocessing
#    * Fill missing values
#    * Remove the feature values whose occurrences are very rare, etc.
#
# 2. Preprocessing by Pandas using the following command:
#    ```shell
#    $ bash preprocess.sh 1 wdl_data pandas 1 1 100
#    ```
#
#    Meanings of the command line arguments:
#    * The 1st argument represents the dataset postfix. It is `1` here since `day_1` is used.
#    * The 2nd argument `wdl_data` is where the preprocessed data is stored.
#    * The 3rd argument `pandas` is the processing script going to use, here we choose `pandas`.
#    * The 4th argument `1` embodies that the normalization is applied to dense features.
#    * The 5th argument `1` means that the feature crossing is applied.
#    * The 6th argument `100` means the number of data files in each file list.
#
#    For more details about the data preprocessing, please refer to [Preprocess the Criteo Dataset](../samples/criteo#preprocess-the-dataset).
#
# 3. Create a soft link of the dataset folder to the path of this notebook using the following command:
#    ```shell
#    $ ln -s ${project_root}/tools/wdl_data ${project_root}/notebooks/wdl_data
#    ```

# %% [markdown]
# <a id="22"></a>
# ### 2.2 Continuous Training with High-level API
# This section gives the code sample of continuous training using Keras-like high-level API. The high-level API encapsulates most of the complexity for users, making it easy to use and able to handle most of scenarios in a production environment.
#
# Meanwhile, HugeCTR also provides the low-level APIs besides its high-level counterpart to allow you customize the training logic. A code sample using the low-level APIs is provided in the next section.
#
# The code sample in this section trains a model from scratch using model oversubscriber, gets the incremental model, and saves the trained dense weights and sparse embedding weights. The following steps are required to achieve those logics:
#
# 1. Create the `solver`, `reader`, `optimizer` and `mos`, then initialize the model.
# 2. Construct the model graph by adding input, sparse embedding, and dense layers in order.
# 3. Compile the model and overview the model graph.
# 4. Dump the model graph to the JSON file.
# 5. Train the sparse and dense model.
# 6. Set the new training datasets and their corresponding keysets.
# 7. Train the sparse and dense model incrementally.
# 8. Get the incrementally trained embedding table.
# 9. Save the model weights and optimizer states explicitly.
#
# Note: `repeat_dataset` should be `False` when using the model oversubscriber, while the argument `num_epochs` in `Model::fit` specifies the number of training epochs in this mode.

# %%
# %%writefile wdl_train.py
import hugectr
from mpi4py import MPI
solver = hugectr.CreateSolver(max_eval_batches = 5000,
                              batchsize_eval = 1024,
                              batchsize = 1024,
                              lr = 0.001,
                              vvgpu = [[0]],
                              i64_input_key = False,
                              use_mixed_precision = False,
                              repeat_dataset = False,
                              use_cuda_graph = True)
reader = hugectr.DataReaderParams(data_reader_type = hugectr.DataReaderType_t.Norm,
                          source = ["wdl_data/file_list."+str(i)+".txt" for i in range(2)],
                          keyset = ["wdl_data/file_list."+str(i)+".keyset" for i in range(2)],
                          eval_source = "wdl_data/file_list.2.txt",
                          check_type = hugectr.Check_t.Sum)
optimizer = hugectr.CreateOptimizer(optimizer_type = hugectr.Optimizer_t.Adam)
hc_cnfg = hugectr.CreateHMemCache(num_blocks = 2, target_hit_rate = 0.5, max_num_evict = 0)
mos = hugectr.CreateMOS(ps_types = [hugectr.TrainPSType_t.Staged, hugectr.TrainPSType_t.Cached],
                        sparse_models = ["./wdl_0_sparse_model", "./wdl_1_sparse_model"],
                        local_paths = ["./"], hmem_cache_configs = [hc_cnfg])
model = hugectr.Model(solver, reader, optimizer, mos)
model.add(hugectr.Input(label_dim = 1, label_name = "label",
                        dense_dim = 13, dense_name = "dense",
                        data_reader_sparse_param_array = 
                        [hugectr.DataReaderSparseParam("wide_data", 30, True, 1),
                        hugectr.DataReaderSparseParam("deep_data", 2, False, 26)]))
model.add(hugectr.SparseEmbedding(embedding_type = hugectr.Embedding_t.DistributedSlotSparseEmbeddingHash, 
                            workspace_size_per_gpu_in_mb = 23,
                            embedding_vec_size = 1,
                            combiner = "sum",
                            sparse_embedding_name = "sparse_embedding2",
                            bottom_name = "wide_data",
                            optimizer = optimizer))
model.add(hugectr.SparseEmbedding(embedding_type = hugectr.Embedding_t.DistributedSlotSparseEmbeddingHash, 
                            workspace_size_per_gpu_in_mb = 358,
                            embedding_vec_size = 16,
                            combiner = "sum",
                            sparse_embedding_name = "sparse_embedding1",
                            bottom_name = "deep_data",
                            optimizer = optimizer))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.Reshape,
                            bottom_names = ["sparse_embedding1"],
                            top_names = ["reshape1"],
                            leading_dim=416))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.Reshape,
                            bottom_names = ["sparse_embedding2"],
                            top_names = ["reshape2"],
                            leading_dim=1))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.Concat,
                            bottom_names = ["reshape1", "dense"], top_names = ["concat1"]))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.InnerProduct,
                            bottom_names = ["concat1"],
                            top_names = ["fc1"],
                            num_output=1024))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.ReLU,
                            bottom_names = ["fc1"],
                            top_names = ["relu1"]))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.Dropout,
                            bottom_names = ["relu1"],
                            top_names = ["dropout1"],
                            dropout_rate=0.5))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.InnerProduct,
                            bottom_names = ["dropout1"],
                            top_names = ["fc2"],
                            num_output=1024))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.ReLU,
                            bottom_names = ["fc2"],
                            top_names = ["relu2"]))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.Dropout,
                            bottom_names = ["relu2"],
                            top_names = ["dropout2"],
                            dropout_rate=0.5))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.InnerProduct,
                            bottom_names = ["dropout2"],
                            top_names = ["fc3"],
                            num_output=1))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.Add,
                            bottom_names = ["fc3", "reshape2"],
                            top_names = ["add1"]))
model.add(hugectr.DenseLayer(layer_type = hugectr.Layer_t.BinaryCrossEntropyLoss,
                            bottom_names = ["add1", "label"],
                            top_names = ["loss"]))
model.compile()
model.summary()
model.graph_to_json(graph_config_file = "wdl.json")
model.fit(num_epochs = 1, display = 500, eval_interval = 1000)
# Get the updated embedding features in model.fit()
# updated_model = model.get_incremental_model()
model.set_source(source = ["wdl_data/file_list.3.txt", "wdl_data/file_list.4.txt"], keyset = ["wdl_data/file_list.3.keyset", "wdl_data/file_list.4.keyset"], eval_source = "wdl_data/file_list.5.txt")
model.fit(num_epochs = 1, display = 500, eval_interval = 1000)
# Get the updated embedding features in model.fit()
updated_model = model.get_incremental_model()
model.save_params_to_files("wdl_mos")
# Out:
# Overwriting wdl_train.py

# %%
# !python3 wdl_train.py
# Out:
# [HUGECTR][11:24:19][INFO][RANK0]: Empty embedding, trained table will be stored in ./wdl_0_sparse_model
# [HUGECTR][11:24:19][INFO][RANK0]: Empty embedding, trained table will be stored in ./wdl_1_sparse_model
# HugeCTR Version: 3.2
# ====================================================Model Init=====================================================
# [HUGECTR][11:24:19][INFO][RANK0]: Global seed is 991506316
# [HUGECTR][11:24:19][INFO][RANK0]: Device to NUMA mapping:
#   GPU 0 ->  node 0
#
# [HUGECTR][11:24:20][WARNING][RANK0]: Peer-to-peer access cannot be fully enabled.
# [HUGECTR][11:24:20][INFO][RANK0]: Start all2all warmup
# [HUGECTR][11:24:20][INFO][RANK0]: End all2all warmup
# [HUGECTR][11:24:20][INFO][RANK0]: Using All-reduce algorithm: NCCL
# [HUGECTR][11:24:20][INFO][RANK0]: Device 0: Tesla V100-SXM2-32GB
# [HUGECTR][11:24:20][INFO][RANK0]: num of DataReader workers: 12
# [HUGECTR][11:24:20][INFO][RANK0]: max_vocabulary_size_per_gpu_=6029312
# [HUGECTR][11:24:20][INFO][RANK0]: max_vocabulary_size_per_gpu_=5865472
# ===================================================Model Compile===================================================
# [HUGECTR][11:24:24][INFO][RANK0]: gpu0 start to init embedding
# [HUGECTR][11:24:24][INFO][RANK0]: gpu0 init embedding done
# [HUGECTR][11:24:24][INFO][RANK0]: gpu0 start to init embedding
# [HUGECTR][11:24:24][INFO][RANK0]: gpu0 init embedding done
# [HUGECTR][11:24:24][INFO][RANK0]: Enable HMEM-Based Parameter Server
# [HUGECTR][11:24:24][INFO][RANK0]: ./wdl_0_sparse_model not exist, create and train from scratch
# [HUGECTR][11:24:24][INFO][RANK0]: Enable HMemCache-Based Parameter Server
# [HUGECTR][11:24:24][INFO][RANK0]: ./wdl_1_sparse_model/key doesn't exist, created
# [HUGECTR][11:24:24][INFO][RANK0]: ./wdl_1_sparse_model/emb_vector doesn't exist, created
# [HUGECTR][11:24:24][INFO][RANK0]: ./wdl_1_sparse_model/Adam.m doesn't exist, created
# [HUGECTR][11:24:24][INFO][RANK0]: ./wdl_1_sparse_model/Adam.v doesn't exist, created
# [HUGECTR][11:24:25][INFO][RANK0]: Starting AUC NCCL warm-up
# [HUGECTR][11:24:25][INFO][RANK0]: Warm-up done
# ===================================================Model Summary===================================================
# label                                   Dense                         Sparse
# label                                   dense                          wide_data,deep_data
# (None, 1)                               (None, 13)
# ------------------------------------------------------------------------------------------------------------------
# Layer Type                              Input Name                    Output Name                   Output Shape
# ------------------------------------------------------------------------------------------------------------------
# DistributedSlotSparseEmbeddingHash      wide_data                     sparse_embedding2             (None, 1, 1)
# DistributedSlotSparseEmbeddingHash      deep_data                     sparse_embedding1             (None, 26, 16)
# Reshape                                 sparse_embedding1             reshape1                      (None, 416)
# Reshape                                 sparse_embedding2             reshape2                      (None, 1)
# Concat                                  reshape1,dense                concat1                       (None, 429)
# InnerProduct                            concat1                       fc1                           (None, 1024)
# ReLU                                    fc1                           relu1                         (None, 1024)
# Dropout                                 relu1                         dropout1                      (None, 1024)
# InnerProduct                            dropout1                      fc2                           (None, 1024)
# ReLU                                    fc2                           relu2                         (None, 1024)
# Dropout                                 relu2                         dropout2                      (None, 1024)
# InnerProduct                            dropout2                      fc3                           (None, 1)
# Add                                     fc3,reshape2                  add1                          (None, 1)
# BinaryCrossEntropyLoss                  add1,label                    loss
# ------------------------------------------------------------------------------------------------------------------
# [HUGECTR][11:24:25][INFO][RANK0]: Save the model graph to wdl.json successfully
# =====================================================Model Fit=====================================================
# [HUGECTR][11:24:25][INFO][RANK0]: Use model oversubscriber mode with number of training sources: 2, number of epochs: 1
# [HUGECTR][11:24:25][INFO][RANK0]: Training batchsize: 1024, evaluation batchsize: 1024
# [HUGECTR][11:24:25][INFO][RANK0]: Evaluation interval: 1000, snapshot interval: 10000
# [HUGECTR][11:24:25][INFO][RANK0]: Sparse embedding trainable: 1, dense network trainable: 1
# [HUGECTR][11:24:25][INFO][RANK0]: Use mixed precision: 0, scaler: 1, use cuda graph: -1233688295
# [HUGECTR][11:24:25][INFO][RANK0]: lr: 0.001000, warmup_steps: 1, decay_start: 0, decay_steps: 1, decay_power: 2.000000, end_lr: 0.000000
# [HUGECTR][11:24:25][INFO][RANK0]: Evaluation source file: wdl_data/file_list.2.txt
# [HUGECTR][11:24:25][INFO][RANK0]: --------------------Epoch 0, source file: wdl_data/file_list.0.txt--------------------
# [HUGECTR][11:24:25][INFO][RANK0]: Preparing embedding table for next pass
# [HUGECTR][11:24:26][INFO][RANK0]: Hit rate [load]: 0 %
# [HUGECTR][11:24:28][INFO][RANK0]: Iter: 500 Time(500 iters): 2.789033s Loss: 0.142556 lr:0.001000
# [HUGECTR][11:24:31][INFO][RANK0]: Iter: 1000 Time(500 iters): 2.422325s Loss: 0.128493 lr:0.001000
# [HUGECTR][11:24:33][INFO][RANK0]: Evaluation, AUC: 0.737397
# [HUGECTR][11:24:33][INFO][RANK0]: Eval Time for 5000 iters: 1.993451s
# [HUGECTR][11:24:35][INFO][RANK0]: Iter: 1500 Time(500 iters): 4.418678s Loss: 0.151482 lr:0.001000
# [HUGECTR][11:24:37][INFO][RANK0]: Iter: 2000 Time(500 iters): 2.420985s Loss: 0.121299 lr:0.001000
# [HUGECTR][11:24:39][INFO][RANK0]: Evaluation, AUC: 0.743639
# [HUGECTR][11:24:39][INFO][RANK0]: Eval Time for 5000 iters: 1.917815s
# [HUGECTR][11:24:42][INFO][RANK0]: Iter: 2500 Time(500 iters): 4.342775s Loss: 0.132627 lr:0.001000
# [HUGECTR][11:24:44][INFO][RANK0]: Iter: 3000 Time(500 iters): 2.422158s Loss: 0.115922 lr:0.001000
# [HUGECTR][11:24:46][INFO][RANK0]: Evaluation, AUC: 0.750783
# [HUGECTR][11:24:46][INFO][RANK0]: Eval Time for 5000 iters: 1.919827s
# [HUGECTR][11:24:49][INFO][RANK0]: Iter: 3500 Time(500 iters): 4.345158s Loss: 0.144952 lr:0.001000
# [HUGECTR][11:24:51][INFO][RANK0]: Iter: 4000 Time(500 iters): 2.417026s Loss: 0.132944 lr:0.001000
# [HUGECTR][11:24:53][INFO][RANK0]: Evaluation, AUC: 0.753165
# [HUGECTR][11:24:53][INFO][RANK0]: Eval Time for 5000 iters: 1.931913s
# [HUGECTR][11:24:53][INFO][RANK0]: --------------------Epoch 0, source file: wdl_data/file_list.1.txt--------------------
# [HUGECTR][11:24:53][INFO][RANK0]: Preparing embedding table for next pass
# [HUGECTR][11:24:54][INFO][RANK0]: Hit rate [dump]: 0 %
# [HUGECTR][11:24:55][INFO][RANK0]: Hit rate [load]: 0 %
# [HUGECTR][11:24:57][INFO][RANK0]: Iter: 4500 Time(500 iters): 6.149843s Loss: 0.130271 lr:0.001000
# [HUGECTR][11:25:00][INFO][RANK0]: Iter: 5000 Time(500 iters): 2.420741s Loss: 0.113828 lr:0.001000
# [HUGECTR][11:25:01][INFO][RANK0]: Evaluation, AUC: 0.754135
# [HUGECTR][11:25:01][INFO][RANK0]: Eval Time for 5000 iters: 1.929446s
# [HUGECTR][11:25:04][INFO][RANK0]: Iter: 5500 Time(500 iters): 4.353039s Loss: 0.120815 lr:0.001000
# [HUGECTR][11:25:06][INFO][RANK0]: Iter: 6000 Time(500 iters): 2.421403s Loss: 0.143363 lr:0.001000
# [HUGECTR][11:25:08][INFO][RANK0]: Evaluation, AUC: 0.755763
# [HUGECTR][11:25:08][INFO][RANK0]: Eval Time for 5000 iters: 1.917598s
# [HUGECTR][11:25:11][INFO][RANK0]: Iter: 6500 Time(500 iters): 4.341800s Loss: 0.162096 lr:0.001000
# [HUGECTR][11:25:13][INFO][RANK0]: Iter: 7000 Time(500 iters): 2.421944s Loss: 0.123990 lr:0.001000
# [HUGECTR][11:25:15][INFO][RANK0]: Evaluation, AUC: 0.756575
# [HUGECTR][11:25:15][INFO][RANK0]: Eval Time for 5000 iters: 1.914259s
# [HUGECTR][11:25:17][INFO][RANK0]: Iter: 7500 Time(500 iters): 4.339739s Loss: 0.143531 lr:0.001000
# [HUGECTR][11:25:20][INFO][RANK0]: Iter: 8000 Time(500 iters): 2.423672s Loss: 0.110065 lr:0.001000
# [HUGECTR][11:25:22][INFO][RANK0]: Evaluation, AUC: 0.757414
# [HUGECTR][11:25:22][INFO][RANK0]: Eval Time for 5000 iters: 1.941024s
# =====================================================Model Fit=====================================================
# [HUGECTR][11:25:22][INFO][RANK0]: Use model oversubscriber mode with number of training sources: 2, number of epochs: 1
# [HUGECTR][11:25:22][INFO][RANK0]: Training batchsize: 1024, evaluation batchsize: 1024
# [HUGECTR][11:25:22][INFO][RANK0]: Evaluation interval: 1000, snapshot interval: 10000
# [HUGECTR][11:25:22][INFO][RANK0]: Sparse embedding trainable: 1, dense network trainable: 1
# [HUGECTR][11:25:22][INFO][RANK0]: Use mixed precision: 0, scaler: 1, use cuda graph: -1233688295
# [HUGECTR][11:25:22][INFO][RANK0]: lr: 0.001000, warmup_steps: 1, decay_start: 0, decay_steps: 1, decay_power: 2.000000, end_lr: 0.000000
# [HUGECTR][11:25:22][INFO][RANK0]: Evaluation source file: wdl_data/file_list.5.txt
# [HUGECTR][11:25:22][INFO][RANK0]: --------------------Epoch 0, source file: wdl_data/file_list.3.txt--------------------
# [HUGECTR][11:25:22][INFO][RANK0]: Preparing embedding table for next pass
# [HUGECTR][11:25:23][INFO][RANK0]: Hit rate [dump]: 77.89 %
# [HUGECTR][11:25:23][INFO][RANK0]: Hit rate [load]: 71.22 %
# [HUGECTR][11:25:26][INFO][RANK0]: Iter: 500 Time(500 iters): 3.964535s Loss: 0.124512 lr:0.001000
# [HUGECTR][11:25:28][INFO][RANK0]: Iter: 1000 Time(500 iters): 2.420492s Loss: 0.139918 lr:0.001000
# [HUGECTR][11:25:30][INFO][RANK0]: Evaluation, AUC: 0.757219
# [HUGECTR][11:25:30][INFO][RANK0]: Eval Time for 5000 iters: 1.924521s
# [HUGECTR][11:25:33][INFO][RANK0]: Iter: 1500 Time(500 iters): 4.351112s Loss: 0.124750 lr:0.001000
# [HUGECTR][11:25:35][INFO][RANK0]: Iter: 2000 Time(500 iters): 2.424692s Loss: 0.129695 lr:0.001000
# [HUGECTR][11:25:37][INFO][RANK0]: Evaluation, AUC: 0.757625
# [HUGECTR][11:25:37][INFO][RANK0]: Eval Time for 5000 iters: 1.942265s
# [HUGECTR][11:25:39][INFO][RANK0]: Iter: 2500 Time(500 iters): 4.366027s Loss: 0.136759 lr:0.001000
# [HUGECTR][11:25:42][INFO][RANK0]: Iter: 3000 Time(500 iters): 2.420878s Loss: 0.125071 lr:0.001000
# [HUGECTR][11:25:44][INFO][RANK0]: Evaluation, AUC: 0.758083
# [HUGECTR][11:25:44][INFO][RANK0]: Eval Time for 5000 iters: 1.919435s
# [HUGECTR][11:25:46][INFO][RANK0]: Iter: 3500 Time(500 iters): 4.345712s Loss: 0.124375 lr:0.001000
# [HUGECTR][11:25:49][INFO][RANK0]: Iter: 4000 Time(500 iters): 2.416976s Loss: 0.143897 lr:0.001000
# [HUGECTR][11:25:50][INFO][RANK0]: Evaluation, AUC: 0.761013
# [HUGECTR][11:25:50][INFO][RANK0]: Eval Time for 5000 iters: 1.932216s
# [HUGECTR][11:25:50][INFO][RANK0]: --------------------Epoch 0, source file: wdl_data/file_list.4.txt--------------------
# [HUGECTR][11:25:50][INFO][RANK0]: Preparing embedding table for next pass
# [HUGECTR][11:25:52][INFO][RANK0]: Hit rate [dump]: 64.88 %
# [HUGECTR][11:25:53][INFO][RANK0]: Hit rate [load]: 67.35 %
# [HUGECTR][11:25:55][INFO][RANK0]: Iter: 4500 Time(500 iters): 6.909246s Loss: 0.161558 lr:0.001000
# [HUGECTR][11:25:58][INFO][RANK0]: Iter: 5000 Time(500 iters): 2.423355s Loss: 0.110863 lr:0.001000
# [HUGECTR][11:26:00][INFO][RANK0]: Evaluation, AUC: 0.760564
# [HUGECTR][11:26:00][INFO][RANK0]: Eval Time for 5000 iters: 1.929626s
# [HUGECTR][11:26:02][INFO][RANK0]: Iter: 5500 Time(500 iters): 4.353155s Loss: 0.154089 lr:0.001000
# [HUGECTR][11:26:05][INFO][RANK0]: Iter: 6000 Time(500 iters): 2.421750s Loss: 0.122991 lr:0.001000
# [HUGECTR][11:26:07][INFO][RANK0]: Evaluation, AUC: 0.759164
# [HUGECTR][11:26:07][INFO][RANK0]: Eval Time for 5000 iters: 1.915490s
# [HUGECTR][11:26:09][INFO][RANK0]: Iter: 6500 Time(500 iters): 4.339465s Loss: 0.131101 lr:0.001000
# [HUGECTR][11:26:11][INFO][RANK0]: Iter: 7000 Time(500 iters): 2.420525s Loss: 0.132860 lr:0.001000
# [HUGECTR][11:26:13][INFO][RANK0]: Evaluation, AUC: 0.760809
# [HUGECTR][11:26:13][INFO][RANK0]: Eval Time for 5000 iters: 1.917547s
# [HUGECTR][11:26:16][INFO][RANK0]: Iter: 7500 Time(500 iters): 4.340905s Loss: 0.097329 lr:0.001000
# [HUGECTR][11:26:18][INFO][RANK0]: Iter: 8000 Time(500 iters): 2.424004s Loss: 0.149156 lr:0.001000
# [HUGECTR][11:26:20][INFO][RANK0]: Evaluation, AUC: 0.762834
# [HUGECTR][11:26:20][INFO][RANK0]: Eval Time for 5000 iters: 1.924606s
# [HUGECTR][11:26:22][INFO][RANK0]: Hit rate [dump]: 64.82 %
# [HUGECTR][11:26:24][INFO][RANK0]: Hit rate [load]: 57.86 %
# [HUGECTR][11:26:24][INFO][RANK0]: Get updated portion of embedding table [DONE}
# [HUGECTR][11:26:25][INFO][RANK0]: Hit rate [dump]: 64.82 %
# [HUGECTR][11:26:25][INFO][RANK0]: Updating sparse model in SSD [DONE]
# [HUGECTR][11:26:27][INFO][RANK0]: Sync blocks from HMEM-Cache to SSD
#   ████████████████████████████████████████▏ 100.0% [   2/   2 | 40.5 Hz | 0s<0s]  m
# [HUGECTR][11:26:27][INFO][RANK0]: Dumping dense weights to file, successful
# [HUGECTR][11:26:27][INFO][RANK0]: Dumping dense optimizer states to file, successful
# [HUGECTR][11:26:27][INFO][RANK0]: Dumping untrainable weights to file, successful

# %% [markdown]
# ### 2.3 Continuous Training with Low-level API
#
# This section gives the code sample of continuous training using low-level API, which follows the same logics as the code sample in above section.
#
# Although the low-level APIs provide fine-grind control to the training logic, we encourage you to use the high-level API if it can satisfy your requirement since the naked data reader and model oversubscriber logics are not straightforward and error prone.
#
# For more about the low-level API, please refer to [Low-level Training API](../docs/python_interface.md#low-level-training-api) and samples of [Low-level Training](./hugectr_criteo.ipynb).

# %%
# %%writefile wdl_mos.py
import hugectr
from mpi4py import MPI
solver = hugectr.CreateSolver(max_eval_batches = 5000,
                              batchsize_eval = 1024,
                              batchsize = 1024,
                              vvgpu = [[0]],
                              i64_input_key = False,
                              use_mixed_precision = False,
                              repeat_dataset = False,
                              use_cuda_graph = True)
reader = hugectr.DataReaderParams(data_reader_type = hugectr.DataReaderType_t.Norm,
                          source = ["wdl_data/file_list."+str(i)+".txt" for i in range(2)],
                          keyset = ["wdl_data/file_list."+str(i)+".keyset" for i in range(2)],
                          eval_source = "wdl_data/file_list.2.txt",
                          check_type = hugectr.Check_t.Sum)
optimizer = hugectr.CreateOptimizer(optimizer_type = hugectr.Optimizer_t.Adam)
hc_cnfg = hugectr.CreateHMemCache(num_blocks = 2, target_hit_rate = 0.5, max_num_evict = 0)
mos = hugectr.CreateMOS(ps_types = [hugectr.TrainPSType_t.Staged, hugectr.TrainPSType_t.Cached],
                        sparse_models = ["./wdl_0_sparse_model", "./wdl_1_sparse_model"],
                        local_paths = ["./"], hmem_cache_configs = [hc_cnfg])
model = hugectr.Model(solver, reader, optimizer, mos)
model.construct_from_json(graph_config_file = "wdl.json", include_dense_network = True)
model.compile()
lr_sch = model.get_learning_rate_scheduler()
data_reader_train = model.get_data_reader_train()
data_reader_eval = model.get_data_reader_eval()
model_oversubscriber = model.get_model_oversubscriber()
dataset = [("wdl_data/file_list."+str(i)+".txt", "wdl_data/file_list."+str(i)+".keyset") for i in range(2)]
data_reader_eval.set_source("wdl_data/file_list.2.txt")
data_reader_eval_flag = True
iteration = 0
for file_list, keyset_file in dataset:
  data_reader_train.set_source(file_list)
  data_reader_train_flag = True
  model_oversubscriber.update(keyset_file)
  while True:
    lr = lr_sch.get_next()
    model.set_learning_rate(lr)
    data_reader_train_flag = model.train()
    if not data_reader_train_flag:
      break
    if iteration % 1000 == 0:
      batches = 0
      while data_reader_eval_flag:
        if batches >= solver.max_eval_batches:
          break
        data_reader_eval_flag = model.eval()
        batches += 1
      if not data_reader_eval_flag:
        data_reader_eval.set_source()
        data_reader_eval_flag = True
      metrics = model.get_eval_metrics()
      print("[HUGECTR][INFO] iter: {}, metrics: {}".format(iteration, metrics))
    iteration += 1
  print("[HUGECTR][INFO] trained with data in {}".format(file_list))

dataset = [("wdl_data/file_list."+str(i)+".txt", "wdl_data/file_list."+str(i)+".keyset") for i in range(3, 5)]
for file_list, keyset_file in dataset:
  data_reader_train.set_source(file_list)
  data_reader_train_flag = True
  model_oversubscriber.update(keyset_file)
  while True:
    lr = lr_sch.get_next()
    model.set_learning_rate(lr)
    data_reader_train_flag = model.train()
    if not data_reader_train_flag:
      break
    if iteration % 1000 == 0:
      batches = 0
      while data_reader_eval_flag:
        if batches >= solver.max_eval_batches:
          break
        data_reader_eval_flag = model.eval()
        batches += 1
      if not data_reader_eval_flag:
        data_reader_eval.set_source()
        data_reader_eval_flag = True
      metrics = model.get_eval_metrics()
      print("[HUGECTR][INFO] iter: {}, metrics: {}".format(iteration, metrics))
    iteration += 1
  print("[HUGECTR][INFO] trained with data in {}".format(file_list))
incremental_model = model.get_incremental_model()
model.save_params_to_files("wdl_mos")
# Out:
# Overwriting wdl_mos.py

# %%
# !python3 wdl_mos.py
# Out:
# [HUGECTR][11:28:27][INFO][RANK0]: Empty embedding, trained table will be stored in ./wdl_0_sparse_model
# [HUGECTR][11:28:27][INFO][RANK0]: Empty embedding, trained table will be stored in ./wdl_1_sparse_model
# HugeCTR Version: 3.2
# ====================================================Model Init=====================================================
# [HUGECTR][11:28:27][INFO][RANK0]: Global seed is 834910547
# [HUGECTR][11:28:27][INFO][RANK0]: Device to NUMA mapping:
#   GPU 0 ->  node 0
#
# [HUGECTR][11:28:29][WARNING][RANK0]: Peer-to-peer access cannot be fully enabled.
# [HUGECTR][11:28:29][INFO][RANK0]: Start all2all warmup
# [HUGECTR][11:28:29][INFO][RANK0]: End all2all warmup
# [HUGECTR][11:28:29][INFO][RANK0]: Using All-reduce algorithm: NCCL
# [HUGECTR][11:28:29][INFO][RANK0]: Device 0: Tesla V100-SXM2-32GB
# [HUGECTR][11:28:29][INFO][RANK0]: num of DataReader workers: 12
# [HUGECTR][11:28:29][INFO][RANK0]: max_num_frequent_categories is not specified using default: 1
# [HUGECTR][11:28:29][INFO][RANK0]: max_num_infrequent_samples is not specified using default: -1
# [HUGECTR][11:28:29][INFO][RANK0]: p_dup_max is not specified using default: 0.010000
# [HUGECTR][11:28:29][INFO][RANK0]: max_all_reduce_bandwidth is not specified using default: 130000000000.000000
# [HUGECTR][11:28:29][INFO][RANK0]: max_all_to_all_bandwidth is not specified using default: 190000000000.000000
# [HUGECTR][11:28:29][INFO][RANK0]: efficiency_bandwidth_ratio is not specified using default: 1.000000
# [HUGECTR][11:28:29][INFO][RANK0]: communication_type is not specified using default: IB_NVLink
# [HUGECTR][11:28:29][INFO][RANK0]: hybrid_embedding_type is not specified using default: Distributed
# [HUGECTR][11:28:29][INFO][RANK0]: max_vocabulary_size_per_gpu_=6029312
# [HUGECTR][11:28:29][INFO][RANK0]: max_num_frequent_categories is not specified using default: 1
# [HUGECTR][11:28:29][INFO][RANK0]: max_num_infrequent_samples is not specified using default: -1
# [HUGECTR][11:28:29][INFO][RANK0]: p_dup_max is not specified using default: 0.010000
# [HUGECTR][11:28:29][INFO][RANK0]: max_all_reduce_bandwidth is not specified using default: 130000000000.000000
# [HUGECTR][11:28:29][INFO][RANK0]: max_all_to_all_bandwidth is not specified using default: 190000000000.000000
# [HUGECTR][11:28:29][INFO][RANK0]: efficiency_bandwidth_ratio is not specified using default: 1.000000
# [HUGECTR][11:28:29][INFO][RANK0]: communication_type is not specified using default: IB_NVLink
# [HUGECTR][11:28:29][INFO][RANK0]: hybrid_embedding_type is not specified using default: Distributed
# [HUGECTR][11:28:29][INFO][RANK0]: max_vocabulary_size_per_gpu_=5865472
# [HUGECTR][11:28:29][INFO][RANK0]: Load the model graph from wdl.json successfully
# ===================================================Model Compile===================================================
# [HUGECTR][11:28:32][INFO][RANK0]: gpu0 start to init embedding
# [HUGECTR][11:28:32][INFO][RANK0]: gpu0 init embedding done
# [HUGECTR][11:28:32][INFO][RANK0]: gpu0 start to init embedding
# [HUGECTR][11:28:32][INFO][RANK0]: gpu0 init embedding done
# [HUGECTR][11:28:32][INFO][RANK0]: Enable HMEM-Based Parameter Server
# [HUGECTR][11:28:32][INFO][RANK0]: ./wdl_0_sparse_model not exist, create and train from scratch
# [HUGECTR][11:28:32][INFO][RANK0]: Enable HMemCache-Based Parameter Server
# [HUGECTR][11:28:32][INFO][RANK0]: ./wdl_1_sparse_model/key doesn't exist, created
# [HUGECTR][11:28:32][INFO][RANK0]: ./wdl_1_sparse_model/emb_vector doesn't exist, created
# [HUGECTR][11:28:32][INFO][RANK0]: ./wdl_1_sparse_model/Adam.m doesn't exist, created
# [HUGECTR][11:28:32][INFO][RANK0]: ./wdl_1_sparse_model/Adam.v doesn't exist, created
# [HUGECTR][11:28:33][INFO][RANK0]: Starting AUC NCCL warm-up
# [HUGECTR][11:28:33][INFO][RANK0]: Warm-up done
# [HUGECTR][11:28:34][INFO][RANK0]: Preparing embedding table for next pass
# [HUGECTR][11:28:34][INFO][RANK0]: Hit rate [load]: 0 %
# [HUGECTR][INFO] iter: 0, metrics: [('AUC', 0.4923926293849945)]
# [HUGECTR][INFO] iter: 1000, metrics: [('AUC', 0.7393015623092651)]
# [HUGECTR][INFO] iter: 2000, metrics: [('AUC', 0.7454283237457275)]
# [HUGECTR][INFO] iter: 3000, metrics: [('AUC', 0.7521467804908752)]
# [HUGECTR][INFO] trained with data in wdl_data/file_list.0.txt
# [HUGECTR][11:29:12][INFO][RANK0]: Preparing embedding table for next pass
# [HUGECTR][11:29:14][INFO][RANK0]: Hit rate [dump]: 0 %
# [HUGECTR][11:29:14][INFO][RANK0]: Hit rate [load]: 0 %
# [HUGECTR][INFO] iter: 4000, metrics: [('AUC', 0.7543743252754211)]
# [HUGECTR][INFO] iter: 5000, metrics: [('AUC', 0.7554132342338562)]
# [HUGECTR][INFO] iter: 6000, metrics: [('AUC', 0.7570464015007019)]
# [HUGECTR][INFO] iter: 7000, metrics: [('AUC', 0.7589923143386841)]
# [HUGECTR][INFO] trained with data in wdl_data/file_list.1.txt
# [HUGECTR][11:29:52][INFO][RANK0]: Preparing embedding table for next pass
# [HUGECTR][11:29:55][INFO][RANK0]: Hit rate [dump]: 77.89 %
# [HUGECTR][11:29:55][INFO][RANK0]: Hit rate [load]: 71.22 %
# [HUGECTR][INFO] iter: 8000, metrics: [('AUC', 0.7602779865264893)]
# [HUGECTR][INFO] iter: 9000, metrics: [('AUC', 0.757955014705658)]
# [HUGECTR][INFO] iter: 10000, metrics: [('AUC', 0.7605931758880615)]
# [HUGECTR][INFO] iter: 11000, metrics: [('AUC', 0.7592945694923401)]
# [HUGECTR][INFO] trained with data in wdl_data/file_list.3.txt
# [HUGECTR][11:30:34][INFO][RANK0]: Preparing embedding table for next pass
# [HUGECTR][11:30:37][INFO][RANK0]: Hit rate [dump]: 64.88 %
# [HUGECTR][11:30:39][INFO][RANK0]: Hit rate [load]: 67.35 %
# [HUGECTR][INFO] iter: 12000, metrics: [('AUC', 0.7618024945259094)]
# [HUGECTR][INFO] iter: 13000, metrics: [('AUC', 0.7609983086585999)]
# [HUGECTR][INFO] iter: 14000, metrics: [('AUC', 0.761036217212677)]
# [HUGECTR][INFO] iter: 15000, metrics: [('AUC', 0.7618542909622192)]
# [HUGECTR][INFO] trained with data in wdl_data/file_list.4.txt
# [HUGECTR][11:31:22][INFO][RANK0]: Hit rate [dump]: 64.82 %
# [HUGECTR][11:31:24][INFO][RANK0]: Hit rate [load]: 63.85 %
# [HUGECTR][11:31:24][INFO][RANK0]: Get updated portion of embedding table [DONE}
# [HUGECTR][11:31:26][INFO][RANK0]: Hit rate [dump]: 64.82 %
# [HUGECTR][11:31:26][INFO][RANK0]: Updating sparse model in SSD [DONE]
# [HUGECTR][11:31:28][INFO][RANK0]: Sync blocks from HMEM-Cache to SSD
#   ████████████████████████████████████████▏ 100.0% [   2/   2 | 34.9 Hz | 0s<0s]  m
# [HUGECTR][11:31:28][INFO][RANK0]: Dumping dense weights to file, successful
# [HUGECTR][11:31:28][INFO][RANK0]: Dumping dense optimizer states to file, successful
# [HUGECTR][11:31:28][INFO][RANK0]: Dumping untrainable weights to file, successful
